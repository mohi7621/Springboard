# %% [markdown]
# This notebook is to establish a baseline that the end model is intended to outperform. The baseline is a simple linear regression model of yearly electricity usage versus square footage of each residence (TOTSQFT)

# %%
# %pylab inline 

import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

# special matplotlib argument for improved plots
from matplotlib import rcParams
sns.set_style("whitegrid")
sns.set_context("poster")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.DataFrame.from_csv('cap-data/data-clean-round1/data_v2.csv', index_col= 0, encoding = 'utf-8')
nweight = pd.DataFrame.from_csv('cap-data/data-clean-round1/nweight.csv', index_col= 0, encoding = 'utf-8')
pc = pd.DataFrame.from_csv('cap-data/data-clean-round1/pc_v2.csv', index_col= 0, encoding = 'utf-8')
kwh = pd.DataFrame.from_csv('cap-data/data-clean-round1/kwh.csv', index_col= 0, encoding = 'utf-8')
pc_cat = pd.DataFrame.from_csv('cap-data/data-clean-round1/pc_cat_vars.csv', index_col= 0, encoding = 'utf-8')

# %% [markdown]
# ## Nemanja: There is something called NWEIGHT associated with each data point. NWEIGHT is the number of residences in the US that the associated data point represents. What is the best way to incorporate NWEIGHT into my baseline regression?

# %% [markdown]
# ### Fitting Linear Regression using `sklearn`

# %%
from sklearn.model_selection import train_test_split

# %%
# x = data['TOTSQFT_EN']
# x = x.reshape(len(x),1)
x1 = data['TOTSQFT']
x1 = x1.reshape(len(x1),1)
y = kwh.KWH
nwgt = nweight.NWEIGHT.as_matrix()

# This creates a LinearRegression object
lm = LinearRegression(fit_intercept = False)
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=False, n_jobs=1, normalize=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(x1, kwh, test_size=0.4)

# %% [markdown]
# ### Train the Model

# %%
lm = LinearRegression(fit_intercept = True)
lm.fit(X_train, y_train)
pred1 = lm.predict(X_train)
res = pred1 - y_train # Residuals
plt.scatter(X_train, res)
plt.ylabel("Residuals")
plt.xlabel("Total SQFT")
plt.title("Residuals Predicting KWH/yr with training data")
print(lm.score(X_train, y_train))
# Out:
# 0.149858456891

# %% [markdown]
# ### Test the model

# %%
pred2 = lm.predict(X_test)
res_test = pred2 - y_test # Residuals
plt.scatter(X_test, res_test)
plt.ylabel("Residuals")
plt.xlabel("Total SQFT")
plt.title("Residuals Predicting KWH/yr with test data")
print(lm.score(X_test, y_test))
# Out:
# 0.147118092736

# %% [markdown]
# ### Nemanja: My baseline model is a simple linear regression, but my ultimate model will use different methods. What model metrics can I use that will translate between model types? I can't use false positive/ false negative etc because my output in the case of predicting KWH used per year is a continuum, not categorical (although, it might be appropriate to make the output categorical by assigning values to ranges of KWH).

# %% [markdown]
# ### Legacy code

# %%
# lm = LinearRegression(fit_intercept=True)
# lm.fit(x, y, nwgt)
# pred = lm.predict(x)
# res = pred-y
# plt.scatter(x, pred-y)
# plt.ylabel("Residuals")
# plt.xlabel("Total SQFT")
# plt.title("comparing model to data with no intercept")
# print(lm.score(x, y))
